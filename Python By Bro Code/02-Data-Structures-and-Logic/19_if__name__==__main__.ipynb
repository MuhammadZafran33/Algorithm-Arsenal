# %%
# if__name__==__main__: (this script can be Imported OR run standalone)
#                       Functions and classes in this module can be reused without the mainblock of code executing..

# %%
print(__name__)
# Out:
# __main__

# %%
def favorite_food(food):
    print(f"Your favorite food is {food}")

def favorite_drink(drink):
    print(f"Your favorite drink is {drink}")

def main():
    print("This is script...")
    favorite_food("Kabuli Polaw")
    favorite_drink("coffee")
    print('Goodbye!')

if __name__ == '__main__':
    main()
# Out:
# This is script...
# Your favorite food is Kabuli Polaw
# Your favorite drink is coffee
# Goodbye!
