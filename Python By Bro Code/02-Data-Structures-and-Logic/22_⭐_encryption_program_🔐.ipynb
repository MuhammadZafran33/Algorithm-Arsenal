# %%
import random
import string

# --- SETUP ---
chars = " " + string.punctuation + string.digits + string.ascii_letters
chars = list(chars)
key = chars.copy()

random.shuffle(key)

# Optional: Print the lists to see the shuffle mapping
# print(f"chars: {chars}")
# print(f"key  : {key}")


# --- ENCRYPT ---
plain_text = input("Enter a message to encrypt: ")
cipher_text = ""

for letter in plain_text:
    index = chars.index(letter)
    cipher_text += key[index]

print("\n--- ENCRYPTION RESULTS ---")
print(f"original message : {plain_text}")
print(f"encrypted message: {cipher_text}")


# --- DECRYPT ---
decrypted_text = ""

for letter in cipher_text:
    index = key.index(letter)
    decrypted_text += chars[index]

print("\n--- DECRYPTION RESULTS ---")
print(f"cipher text      : {cipher_text}")
print(f"decrypted message: {decrypted_text}")
# Out:
# --- ENCRYPTION RESULTS ---
# original message : I like pizza!
# encrypted message: q;gXt*;7X99HS
#
# --- DECRYPTION RESULTS ---
# cipher text      : q;gXt*;7X99HS
# decrypted message: I like pizza!
