# %% [markdown]
# ### LOGICAL OPERATORS........

# %%
temp = float(input("Enter the Current Temperature plz"))
is_raining = False

if temp > 35 or temp < 0 or is_raining:
    print("The outdoor event is cancel! ")
else:
    print("The outdoor event is still possible! ")
# Out:
# The outdoor event is still possible!

# %%
temp = float(input("Enter the Current Temperature plz"))
is_sunny= True

if temp >= 25 and is_sunny:
    print("The outdoor event is cancel bec it is HOT outside 🥵♨️! ")
else:
    print("The outdoor event is still possible bc the mosam is do good ! ")
# Out:
# The outdoor event is cancel bec it is HOT outside 🥵♨️!

# %%
23
