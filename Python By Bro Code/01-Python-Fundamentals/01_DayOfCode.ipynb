# %% [markdown]
# # Bro Code Day 01...........

# %%
print("I like pizza")
print("its pretty Good")
# Out:
# I like pizza
# its pretty Good

# %%
first_name = "Bro"
food = "pizza"
email = "Bro1234@fake.com"

print(f"Hallo {first_name}")
print(f"You like {food}")
print(f"My Email is{email}")
# Out:
# Hallo Bro
# You like pizza
# My Email isBro1234@fake.com

# %%
age = 20
quantity = 3
print(f"My age is {age}")
print(f"You are buying {quantity} items")
# Out:
# My age is 20
# You are buying 3 items

# %%
price = 10.99
print(f"the price is ${price} of the item.")
# Out:
# the price is $10.99 of the item.

# %%
is_student = False
if is_student:
    print("You are a student")
else:
    print("you are not a student")
# Out:
# you are not a student

# %%
name = "Zafran khan"
age  = 21
gpa = 3.2
is_student = True
print(type(is_student))
print(f"my name is {name}, age is {age} having gpa {gpa} as a student od im sciences {is_student}")
gpa = int(gpa)
print(gpa)
print(type(gpa))
age = str(age)
print(type(age))
age += "1"
print(age)
name = bool(name)
print(name)
# Out:
# <class 'bool'>
# my name is Zafran khan, age is 21 having gpa 3.2 as a student od im sciences True
# 3
# <class 'int'>
# <class 'str'>
# 211
# True

# %% [markdown]
# ###### **TypeCasting:** the process of converting a variable from one datatype to another  eg: str(), int(), float(), bool()
