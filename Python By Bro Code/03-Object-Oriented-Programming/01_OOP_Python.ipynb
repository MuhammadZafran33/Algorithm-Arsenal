# %%
# OBJECT = A "bundle" of related attributes (variables) and methods (functions) 
#      Ex. phine, cuop, book
#      You need a "Class" to create many objects

# Class = (blueprint) used to design the structure and layout of an object

# %%
class car:
    def __init__(self, model, year, color, for_sale):
        self.model = model
        self.year = year
        self.color = color
        self.for_sale = for_sale
car1  = car("mustang", 2026, "red", False)
car2  = car("BMW", 2025, "Black", True)
car3  = car("Corrola", 2024, "white", False)
print("********** CAR 1 **********")
print(f"MODEL: {car1.model}")
print(car1.year)
print(car1.color)
print(car1.for_sale)

print("********** CAR 2 **********")
print(f"MODEL: {car2.model}")
print(car2.year)
print(car2.color)
print(car2.for_sale)

print("********** CAR 3 **********")
print(f"MODEL: {car3.model}")
print(car3.year)
print(car3.color)
print(car3.for_sale)
# Out:
# ********** CAR 1 **********
# MODEL: mustang
# 2026
# red
# False
# ********** CAR 2 **********
# MODEL: BMW
# 2025
# Black
# True
# ********** CAR 3 **********
# MODEL: Corrola
# 2024
# white
# False

# %%
class Car:
    def __init__(self, model, year, color, for_sale):
        self.model = model
        self.year = year
        self.color = color
        self.for_sale = for_sale

    def drive(self):
        print(f"You drive the {self.color} {self.model}")

    def stop(self):
        print(f"You stop the {self.color} {self.model}")

    def describe(self):
        print(f"{self.year} {self.color} {self.model}")

def main():
    # 1. Create (instantiate) two Car objects
    car1 = Car("Mustang", 2024, "red", False)
    car2 = Car("Corvette", 2025, "blue", True)

    # 2. Test the methods on the first car
    print("--- Car 1 ---")
    car1.describe()
    car1.drive()
    car1.stop()
    print(f"Is it for sale? {car1.for_sale}")

    # 3. Test the methods on the second car
    print("\n--- Car 2 ---")
    car2.describe()
    car2.drive()
    car2.stop()
    print(f"Is it for sale? {car2.for_sale}")

if __name__ == '__main__':
    main()
# Out:
# --- Car 1 ---
# 2024 red Mustang
# You drive the red Mustang
# You stop the red Mustang
# Is it for sale? False
#
# --- Car 2 ---
# 2025 blue Corvette
# You drive the blue Corvette
# You stop the blue Corvette
# Is it for sale? True
