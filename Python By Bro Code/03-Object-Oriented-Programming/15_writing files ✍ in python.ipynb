# %%
# Python writing files (.txt, .json, .csv)

txt_data = "I like Cricket!"

file_path = "output.txt"

with open(file_path, "w") as file:
    file.write(txt_data)
    print(f"txt file '{file_path}' was created")
# Out:
# txt file 'output.txt' was created

# %%
txt_data = "I like pizza!"

file_path = "C:/Users/pts/OneDrive/Desktop/ML Proj/Courses/Bro Code Python/test.txt"

try:
    with open(file_path, "x") as file:
        file.write(txt_data)
        print(f"txt file '{file_path}' was created")
except FileExistsError:
    print("That file already exists!")
# Out:
# That file already exists!

# %%
txt_data = "I like Cricket!"

file_path = "C:/Users/pts/OneDrive/Desktop/ML Proj/Courses/Bro Code Python/test.txt"

try:
    with open(file_path, "a") as file:
        file.write("\n" + txt_data)
        print(f"txt file '{file_path}' was created")
except FileExistsError:
    print("That file already exists!")
# Out:
# txt file 'C:/Users/pts/OneDrive/Desktop/ML Proj/Courses/Bro Code Python/test.txt' was created

# %%
 # Python writing files (.txt, .json, .csv)

import json

employee = {
    "name": "Spongebob",
    "age": 30,
    "job": "cook"
}

file_path = "C:/Users/pts/OneDrive/Desktop/ML Proj/Courses/Bro Code Python/test.json"

try:
    with open(file_path, "w") as file:
        json.dump(employee, file, indent=4)
        print(f"json file '{file_path}' was created")
except FileExistsError:
    print("That file already exists!")
# Out:
# json file 'C:/Users/pts/OneDrive/Desktop/ML Proj/Courses/Bro Code Python/test.json' was created

# %%
# Python writing files (.txt, .json, .csv)

import json
import csv

employees = [["Name", "Age", "Job"],
             ["Spongebob", 30, "Cook"],
             ["Patrick", 37, "Unemployed"],
             ["Sandy", 27, "Scientist"]]

file_path = "C:/Users/pts/OneDrive/Desktop/ML Proj/Courses/Bro Code Python/test.csv"

try:
    with open(file_path, "w", newline="") as file:
        writer = csv.writer(file)
        for row in employees:
            writer.writerow(row)
        print(f"csv file '{file_path}' was created")
except FileExistsError:
    print("That file already exists!")
# Out:
# csv file 'C:/Users/pts/OneDrive/Desktop/ML Proj/Courses/Bro Code Python/test.csv' was created
