# %%
# Python reading files (.txt, .json, .csv)

file_path = "C:/Users/pts/OneDrive/Desktop/ML Proj/Courses/Bro Code Python/test.txt"

try:
    with open(file_path, "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("That file was not found")
except PermissionError:
    print("You do not have permission to read that file")
# Out:
# I like pizza!
# I like Cricket!
# I like Cricket!
# I like Cricket!
# I like Cricket!
# I like Cricket!

# %%
# Python reading files (.txt, .json, .csv)
import json
file_path = "C:/Users/pts/OneDrive/Desktop/ML Proj/Courses/Bro Code Python/test.json"

try:
    with open(file_path, "r") as file:
        content = json.load(file)
        print(content)
        print(content["name"])
        print(content["age"])
        print(content["job"])
except FileNotFoundError:
    print("That file was not found")
except PermissionError:
    print("You do not have permission to read that file")
# Out:
# {'name': 'Spongebob', 'age': 30, 'job': 'cook'}
# Spongebob
# 30
# cook

# %%
# Python reading files (.txt, .json, .csv)
import csv
file_path = "C:/Users/pts/OneDrive/Desktop/ML Proj/Courses/Bro Code Python/test.csv"

try:
    with open(file_path, "r") as file:
        content = csv.reader(file)
        for line in content:
            print(line)
            print("*************")
            print(line[0])
            print(line[1])
            print(line[2]) 
except FileNotFoundError:
    print("That file was not found")
except PermissionError:
    print("You do not have permission to read that file")
# Out:
# ['Name', 'Age', 'Job']
# *************
# Name
# Age
# Job
# ['Spongebob', '30', 'Cook']
# *************
# Spongebob
# 30
# Cook
# ['Patrick', '37', 'Unemployed']
# *************
# Patrick
# 37
# Unemployed
# ['Sandy', '27', 'Scientist']
# *************
# Sandy
# 27
# Scientist
