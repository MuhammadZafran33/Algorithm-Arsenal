# %%
# PyQt5 radio buttons
import sys
from PyQt5.QtWidgets import (
    QApplication,
    QMainWindow,
    QRadioButton,
    QButtonGroup,
)


class MainWindow(QMainWindow):

    def __init__(self):
        super().__init__()
        self.setGeometry(700, 300, 500, 500)
        self.radio1 = QRadioButton("Visa", self)
        self.radio2 = QRadioButton("Mastercard", self)
        self.radio3 = QRadioButton("Gift Card", self)
        self.radio4 = QRadioButton("In-Store", self)
        self.radio5 = QRadioButton("Online", self)
        self.button_group1 = QButtonGroup(self)
        self.button_group2 = QButtonGroup(self)
        self.initUI()

    def initUI(self):
        self.radio1.setGeometry(0, 0, 300, 50)
        self.radio2.setGeometry(0, 50, 300, 50)
        self.radio3.setGeometry(0, 100, 300, 50)
        self.radio4.setGeometry(0, 150, 300, 50)
        self.radio5.setGeometry(0, 200, 300, 50)

        self.setStyleSheet(
            "QRadioButton{" "font-size: 40px;" "font-family: Arial;}"
        )

        self.button_group1.addButton(self.radio1)
        self.button_group1.addButton(self.radio2)
        self.button_group1.addButton(self.radio3)
        self.button_group2.addButton(self.radio4)
        self.button_group2.addButton(self.radio5)

        self.radio1.toggled.connect(self.radio_button_changed)
        self.radio2.toggled.connect(self.radio_button_changed)
        self.radio3.toggled.connect(self.radio_button_changed)
        self.radio4.toggled.connect(self.radio_button_changed)
        self.radio5.toggled.connect(self.radio_button_changed)

    def radio_button_changed(self):
        radio_button = self.sender()
        if radio_button.isChecked():
            print(f"{radio_button.text()} is selected")


if __name__ == "__main__":
    app = QApplication(sys.argv)
    window = MainWindow()
    window.show()
    sys.exit(app.exec_())
# Out:
# Visa is selected
# Gift Card is selected
# In-Store is selected
# Online is selected
# Mastercard is selected
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\pts\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import sys
from PyQt5.QtWidgets import (
    QApplication,
    QMainWindow,
    QWidget,
    QVBoxLayout,
    QHBoxLayout,
    QGroupBox,
    QRadioButton,
    QButtonGroup,
    QLabel,
)
from PyQt5.QtCore import Qt


class MainWindow(QMainWindow):

    def __init__(self):
        super().__init__()
        self.setWindowTitle("Payment & Delivery Selection")
        self.resize(550, 450)
        self.initUI()

    def initUI(self):
        # 1. Main Central Layout
        central_widget = QWidget(self)
        self.setCentralWidget(central_widget)

        main_layout = QVBoxLayout()
        main_layout.setSpacing(20)
        main_layout.setContentsMargins(30, 30, 30, 30)
        central_widget.setLayout(main_layout)

        # 2. Horizontal container for side-by-side option groups
        groups_layout = QHBoxLayout()
        groups_layout.setSpacing(20)

        # --- GROUP 1: Payment Method ---
        payment_box = QGroupBox("Payment Method")
        payment_layout = QVBoxLayout()

        self.radio1 = QRadioButton("Visa")
        self.radio2 = QRadioButton("Mastercard")
        self.radio3 = QRadioButton("Gift Card")

        self.button_group1 = QButtonGroup(self)
        self.button_group1.addButton(self.radio1)
        self.button_group1.addButton(self.radio2)
        self.button_group1.addButton(self.radio3)

        for btn in (self.radio1, self.radio2, self.radio3):
            btn.setCursor(Qt.PointingHandCursor)
            btn.toggled.connect(self.radio_button_changed)
            payment_layout.addWidget(btn)

        payment_box.setLayout(payment_layout)

        # --- GROUP 2: Delivery Method ---
        delivery_box = QGroupBox("Delivery Method")
        delivery_layout = QVBoxLayout()

        self.radio4 = QRadioButton("In-Store")
        self.radio5 = QRadioButton("Online")

        self.button_group2 = QButtonGroup(self)
        self.button_group2.addButton(self.radio4)
        self.button_group2.addButton(self.radio5)

        for btn in (self.radio4, self.radio5):
            btn.setCursor(Qt.PointingHandCursor)
            btn.toggled.connect(self.radio_button_changed)
            delivery_layout.addWidget(btn)

        delivery_box.setLayout(delivery_layout)

        # Add groups to horizontal layout
        groups_layout.addWidget(payment_box)
        groups_layout.addWidget(delivery_box)
        main_layout.addLayout(groups_layout)

        # 3. Dynamic Selection Status Label
        self.status_label = QLabel("Select payment and delivery options", self)
        self.status_label.setAlignment(Qt.AlignCenter)
        main_layout.addWidget(self.status_label)

        # 4. Modern Dark Stylesheet
        self.setStyleSheet("""
            QMainWindow {
                background-color: #0F172A;
            }
            QGroupBox {
                color: #818CF8;
                font-size: 18px;
                font-weight: bold;
                font-family: 'Segoe UI', sans-serif;
                border: 2px solid #334155;
                border-radius: 10px;
                margin-top: 12px;
                padding-top: 20px;
            }
            QGroupBox::title {
                subcontrol-origin: margin;
                left: 15px;
                padding: 0 5px;
            }
            QRadioButton {
                color: #F8FAFC;
                font-size: 16px;
                font-family: 'Segoe UI', sans-serif;
                spacing: 10px;
                padding: 6px 0;
            }
            QRadioButton::indicator {
                width: 20px;
                height: 20px;
                border-radius: 10px;
                border: 2px solid #6366F1;
                background-color: #1E293B;
            }
            QRadioButton::indicator:checked {
                background-color: #6366F1;
                border: 4px solid #1E293B;
            }
            QLabel {
                color: #94A3B8;
                font-size: 16px;
                font-family: 'Segoe UI', sans-serif;
                padding-top: 10px;
            }
        """)

    def radio_button_changed(self):
        radio_button = self.sender()
        if radio_button.isChecked():
            print(f"{radio_button.text()} is selected")
            pay = self.button_group1.checkedButton()
            deliv = self.button_group2.checkedButton()

            pay_text = pay.text() if pay else "None"
            deliv_text = deliv.text() if deliv else "None"

            self.status_label.setText(
                f"Selected: 💳 {pay_text}  |  📦 {deliv_text}"
            )


def main():
    app = QApplication(sys.argv)
    window = MainWindow()
    window.show()
    sys.exit(app.exec_())


if __name__ == "__main__":
    main()
# Out:
# Visa is selected
# In-Store is selected
# Online is selected
# Mastercard is selected
# Gift Card is selected
# In-Store is selected
# Visa is selected
# Mastercard is selected
# Gift Card is selected
# Online is selected
# Mastercard is selected
# Visa is selected
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
# Out:
# Hello zafran
# Hello zafran
# Hello zafran
# Hello azizray
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\pts\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# Out:
# Hello Muhammad zafran
# Hello Muhammad zafran khan
# Hello Muhammad zafran khan
# Hello Muhammad zafran khan
# Hello Muhammad zafran khan
# Hello Muhammad zafran khan
# Hello Muhammad zafran khan
# Hello Muhammad zafran khan
# Hello Muhammad zafran khan
# Hello Muhammad zafran khan
# Hello Muhammad zafran khan
# Hello Muhammad zafran khan
# Hello Muhammad zafran khan
# Hello Muhammad zafran khan
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
